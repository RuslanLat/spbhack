# %%
import pandas as pd

# %%
dataset_1 = pd.read_csv('data/datasets/dataset_1.csv', index_col=0)
dataset_1.head()
# Out:
#                                                 address  target_building_id  \
# 4070        196641, Санкт-Петербург г, Школьная ул, д.5             76337.0
# 7573  Санкт-Петербург (г.), Железнодорожный (пр-кт.)...            220011.0
# 5815  198325, Санкт-Петербург г, Красное Село г, Теа...            109979.0
# 2159  195256, Санкт-Петербург (г.), Верности (ул.), ...             72112.0
# 1476  194291, Санкт-Петербург (г.), Кустодиева (ул.)...            186531.0
#
#                                          target_address
# 4070  Санкт-Петербург, город Павловск, Пязелево, Шко...
# 7573  г.Санкт-Петербург, Железнодорожный проспект, д...
# 5815  Санкт-Петербург, город Красное Село, Дудергоф,...
# 2159  г.Санкт-Петербург, улица Верности, дом 28, кор...
# 1476  г.Санкт-Петербург, улица Кустодиева, дом 1, ли...

# %%
dataset_1.isna().sum()
# Out:
# address                0
# target_building_id    12
# target_address        12
# dtype: int64

# %%
dataset_1[dataset_1['target_building_id'].isna()]
# Out:
#                                                  address  target_building_id  \
# 11575  188289, Ленинградская обл, Луга г, Детский гор...                 NaN
# 759               Санкт-Петербург (г.), Володарский (п.)                 NaN
# 9048   197022, Санкт-Петербург (г.), Академика Павлов...                 NaN
# 7927   193168, Санкт-Петербург (г.), Санкт-Петербург ...                 NaN
# 8808   197198, Санкт-Петербург (г.), Петровский (пр-кт.)                 NaN
# 1598   194021, Санкт-Петербург (г.), Санкт-Петербург ...                 NaN
# 3125                        198097, Санкт-Петербург (г.)                 NaN
# 312                                    Санкт-Петербург г                 NaN
# 4728   Санкт-Петербург (г.), Львовская (ул), 195176, д.9                 NaN
# 162    190000, Санкт-Петербург (г.), Санкт-Петербург ...                 NaN
# 12579                          191028, Санкт-Петербург г                 NaN
# ...

# %%
dataset_2 = pd.read_csv('data/datasets/dataset_2.csv', index_col=0)
dataset_2.head()
# Out:
#                            address  target_building_id  \
# 5348  Шмидта лейтенанта наб., д.13               96846
# 2834            9 Советская , д.23               98045
# 4401                 17 линия, д.8               99937
# 4336                15 линия, д.76              124398
# 4642                 7 линия, д.66               28204
#
#                                          target_address
# 5348  г.Санкт-Петербург, набережная Лейтенанта Шмидт...
# 2834  г.Санкт-Петербург, 9-я Советская улица, дом 23...
# 4401  г.Санкт-Петербург, 17-я линия В.О., дом 8, лит...
# 4336  г.Санкт-Петербург, 15-я линия В.О., дом 76, ли...
# 4642  г.Санкт-Петербург, 7-я линия В.О., дом 66, лит...

# %%
dataset_2.isna().sum()
# Out:
# address               0
# target_building_id    0
# target_address        0
# dtype: int64

# %%
dataset_3 = pd.read_csv('data/datasets/dataset_3.csv', index_col=0)
dataset_3.head()
# Out:
#                       address  target_building_id  \
# 3252           Коллонтай, д.6            141557.0
# 4508        Суздальское, д.24            222076.0
# 2381           Посадская, д.3             80115.0
# 3603        Дибуновская, д.19            110947.0
# 1997  Адмирала Черокова, д.22            208028.0
#
#                                          target_address
# 3252  г.Санкт-Петербург, улица Коллонтай, дом 6, кор...
# 4508  г.Санкт-Петербург, Суздальское шоссе, дом 24, ...
# 2381  г.Санкт-Петербург, Малая Посадская улица, дом ...
# 3603  г.Санкт-Петербург, Дибуновская улица, дом 19, ...
# 1997  г.Санкт-Петербург, улица Адмирала Черокова, до...

# %%
dataset_3.isna().sum()
# Out:
# address                0
# target_building_id    46
# target_address        46
# dtype: int64

# %%
dataset_3[dataset_3['target_building_id'].isna()]
# Out:
#                               address  target_building_id target_address
# 2129                  Ленинский, д.32                 NaN            NaN
# 5633                 Меньковская, д.2                 NaN            NaN
# 2045              Хвойный, д.92 (108)                 NaN            NaN
# 4848                   Тельмана, д.38                 NaN            NaN
# 4822                   Тельмана, д.11                 NaN            NaN
# 6671         Шишкина (Торфяное), д.21                 NaN            NaN
# 2007                  Ленинский, д.27                 NaN            NaN
# 2050               Современников, д.3                 NaN            NaN
# 6683               Пригородный, д.439                 NaN            NaN
# 4834                   Тельмана, д.21                 NaN            NaN
# 2090                  Ленинский, д.30                 NaN            NaN
# 4832                   Тельмана, д.19                 NaN            NaN
# ...

# %%
dataset_4 = pd.read_csv('data/datasets/dataset_4.csv', index_col=0)
dataset_4.head()
# Out:
#                           address  target_building_id  \
# 20918  Профессора Попова ул., 2П5               94530
# 17700           Малый пр. ВО, 64А               95527
# 10659              Малая ул., 14А               86117
# 26938       Большой пр. ВО, 90к2з               46590
# 8925           Никольская пл., 1а               28185
#
#                                           target_address
# 20918  г.Санкт-Петербург, улица Профессора Попова, до...
# 17700  г.Санкт-Петербург, Малый проспект В.О., дом 64...
# 10659  г.Санкт-Петербург, Малая Балканская улица, дом...
# 26938  г.Санкт-Петербург, Большой проспект В.О., дом ...
# 8925   г.Санкт-Петербург, Никольская площадь, дом 1, ...

# %%
dataset_4.isna().sum()
# Out:
# address               0
# target_building_id    0
# target_address        0
# dtype: int64

# %%
dataset_5 = pd.read_csv('data/datasets/dataset_5.csv', index_col=0)
dataset_5.head()
# Out:
#                                                   address  target_building_id  \
# 161837   Санкт-Петербург, проспект Авиаконструкторов, 4к1              126974
# 99485            Россия, Санкт-Петербург, улица Бабушкина              130062
# 133939  Санкт-Петербург, Невский район, муниципальный ...               63855
# 104007   Россия, Санкт-Петербург, Будапештская улица, 11В               99699
# 71647          Россия, Санкт-Петербург, территория Лигово               49819
#
#                                            target_address
# 161837  г.Санкт-Петербург, проспект Авиаконструкторов,...
# 99485   г.Санкт-Петербург, улица Бабушкина, дом 123, л...
# 133939  г.Санкт-Петербург, улица Коллонтай, дом 20, ли...
# 104007  г.Санкт-Петербург, Будапештская улица, дом 11,...
# 71647   г.Санкт-Петербург, улица Добровольцев, дом 40,...

# %%
dataset_5.isna().sum()
# Out:
# address               0
# target_building_id    0
# target_address        0
# dtype: int64
